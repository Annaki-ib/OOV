# %%
# !pip install conllu
# Out:
# Requirement already satisfied: conllu in /usr/local/lib/python3.11/dist-packages (6.0.0)

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 92.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %% [markdown]
# ## **data preparation**

# %%
import os
from collections import defaultdict, Counter
import torch  # Corrected import
from conllu import parse_incr

# Constantes
PAD_ID = 0  # Indice pour le padding
UNK_ID = 1  # Indice pour les mots hors vocabulaire (OOV)

def build_vocab(data_file, min_freq=1):
    """
    Construit les vocabulaires des mots (Vw) et des étiquettes (Vi) à partir du fichier de données.
    :param data_file: Chemin vers le fichier de données au format CoNLL-U.
    :param min_freq: Fréquence minimale pour qu'un mot soit inclus dans le vocabulaire.
    :return: Deux dictionnaires : Vw (mots) et Vi (étiquettes POS).
    """
    word_counter = Counter()  # Compteur pour les mots
    pos_counter = Counter()   # Compteur pour les étiquettes POS

    with open(data_file, "r", encoding="utf-8") as f:
        for sentence in parse_incr(f):
            for token in sentence:
                word = token["form"].lower()  # On utilise des minuscules pour normaliser
                pos = token["upos"]
                word_counter[word] += 1
                pos_counter[pos] += 1

    # Construction du vocabulaire des mots (Vw)
    Vw = {"<PAD>": PAD_ID, "<UNK>": UNK_ID}  # On ajoute les tokens spéciaux
    for word, freq in word_counter.items():
        if freq >= min_freq:  # On ignore les mots trop rares
            Vw[word] = len(Vw)  # On assigne un nouvel indice

    # Construction du vocabulaire des étiquettes (Vi)
    Vi = {"<PAD>": PAD_ID}  # On ajoute le token spécial pour le padding
    for pos in pos_counter:
        Vi[pos] = len(Vi)  # On assigne un nouvel indice

    return Vw, Vi

def encode_data(data_file, Vw, Vi):
    """
    Encode les mots et les étiquettes POS en indices à l'aide des vocabulaires Vw et Vi.
    :param data_file: Chemin vers le fichier de données au format CoNLL-U.
    :param Vw: Vocabulaire des mots.
    :param Vi: Vocabulaire des étiquettes POS.
    :return: Une liste de tuples (mots encodés, étiquettes encodées).
    """
    encoded_data = []

    with open(data_file, "r", encoding="utf-8") as f:
        for sentence in parse_incr(f):
            words = []
            pos_tags = []
            for token in sentence:
                word = token["form"].lower()  # On utilise des minuscules pour normaliser
                pos = token["upos"]
                # Encodage des mots (remplacement des OOV par UNK_ID)
                word_idx = Vw.get(word, UNK_ID)
                pos_idx = Vi[pos]
                words.append(word_idx)
                pos_tags.append(pos_idx)
            encoded_data.append((words, pos_tags))

    return encoded_data

def save_vocab(Vw, Vi, output_dir):
    """
    Sauvegarde les vocabulaires Vw et Vi dans des fichiers.
    :param Vw: Vocabulaire des mots.
    :param Vi: Vocabulaire des étiquettes POS.
    :param output_dir: Répertoire de sortie pour sauvegarder les fichiers.
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Sauvegarde du vocabulaire des mots
    with open(os.path.join(output_dir, "vocab_words.txt"), "w", encoding="utf-8") as f:
        for word, idx in Vw.items():
            f.write(f"{word}\t{idx}\n")

    # Sauvegarde du vocabulaire des étiquettes
    with open(os.path.join(output_dir, "vocab_pos.txt"), "w", encoding="utf-8") as f:
        for pos, idx in Vi.items():
            f.write(f"{pos}\t{idx}\n")

def load_vocab(vocab_file):
    """
    Charge un vocabulaire à partir d'un fichier.
    :param vocab_file: Chemin vers le fichier de vocabulaire.
    :return: Un dictionnaire représentant le vocabulaire.
    """
    vocab = {}
    with open(vocab_file, "r", encoding="utf-8") as f:
        for line in f:
            word, idx = line.strip().split("\t")
            vocab[word] = int(idx)
    return vocab

if __name__ == "__main__":
    # Chemin vers le fichier de données d'entraînement
    train_file = "/content/qaf_arabizi-ud-train.conllu"

    # Étape 1 : Construire les vocabulaires
    Vw, Vi = build_vocab(train_file, min_freq=2)  # On ignore les mots qui apparaissent moins de 2 fois
    print(f"Taille du vocabulaire des mots (Vw) : {len(Vw)}")
    print(f"Taille du vocabulaire des étiquettes (Vi) : {len(Vi)}")

    # Étape 2 : Encoder les données d'entraînement
    encoded_train_data = encode_data(train_file, Vw, Vi)
    print(f"Nombre de phrases encodées : {len(encoded_train_data)}")

    # Étape 3 : Sauvegarder les vocabulaires
    save_vocab(Vw, Vi, "vocab")
    print("Vocabulaires sauvegardés dans le dossier 'vocab'.")
# Out:
# Taille du vocabulaire des mots (Vw) : 1443
# Taille du vocabulaire des étiquettes (Vi) : 18
# Nombre de phrases encodées : 1003
# Vocabulaires sauvegardés dans le dossier 'vocab'.

# %%
import os
from collections import Counter
import torch
from conllu import parse_incr

# Constantes
PAD_ID = 0  # Padding
UNK_ID = 1  # Out-of-vocabulary

def build_vocab(data_file, min_freq=1):
    """
    Construit les vocabulaires des mots (Vw) et des étiquettes (Vi).
    """
    word_counter = Counter()
    pos_counter = Counter()
    with open(data_file, "r", encoding="utf-8") as f:
        for sentence in parse_incr(f):
            for token in sentence:
                word = token["form"].lower()
                pos = token["upos"]
                word_counter[word] += 1
                pos_counter[pos] += 1

    Vw = {"<PAD>": PAD_ID, "<UNK>": UNK_ID}
    for word, freq in word_counter.items():
        if freq >= min_freq:
            Vw[word] = len(Vw)

    Vi = {"<PAD>": PAD_ID}
    for pos in pos_counter:
        Vi[pos] = len(Vi)

    return Vw, Vi

def encode_data(data_file, Vw, Vi):
    """
    Encode les phrases et leurs étiquettes en indices.
    """
    encoded_data = []
    with open(data_file, "r", encoding="utf-8") as f:
        for sentence in parse_incr(f):
            word_indices = []
            pos_indices = []
            for token in sentence:
                word = token["form"].lower()
                pos = token["upos"]
                word_idx = Vw.get(word, UNK_ID)
                pos_idx = Vi[pos]
                word_indices.append(word_idx)
                pos_indices.append(pos_idx)
            encoded_data.append((word_indices, pos_indices))
    return encoded_data

def pad_batch(batch, pad_value=PAD_ID):
    """
    Applique le padding à une liste de séquences de longueurs variables.
    """
    from torch.nn.utils.rnn import pad_sequence
    batch_tensors = [torch.tensor(seq, dtype=torch.long) for seq in batch]
    padded_batch = pad_sequence(batch_tensors, batch_first=True, padding_value=pad_value)
    return padded_batch

def save_vocab(Vw, Vi, output_dir):
    """
    Sauvegarde les vocabulaires dans des fichiers.
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    with open(os.path.join(output_dir, "vocab_words.txt"), "w", encoding="utf-8") as f:
        for word, idx in Vw.items():
            f.write(f"{word}\t{idx}\n")
    with open(os.path.join(output_dir, "vocab_pos.txt"), "w", encoding="utf-8") as f:
        for pos, idx in Vi.items():
            f.write(f"{pos}\t{idx}\n")

def load_vocab(vocab_file):
    """
    Charge un vocabulaire depuis un fichier.
    """
    vocab = {}
    with open(vocab_file, "r", encoding="utf-8") as f:
        for line in f:
            token, idx = line.strip().split("\t")
            vocab[token] = int(idx)
    return vocab


if __name__ == "__main__":
    # Chemin vers le fichier de données d'entraînement
    train_file = "/content/qaf_arabizi-ud-train.conllu"

    # Étape 1 : Construire les vocabulaires
    Vw, Vi = build_vocab(train_file, min_freq=2)  # On ignore les mots qui apparaissent moins de 2 fois
    print(f"Taille du vocabulaire des mots (Vw) : {len(Vw)}")
    print(f"Taille du vocabulaire des étiquettes (Vi) : {len(Vi)}")

    # Étape 2 : Encoder les données d'entraînement
    encoded_train_data = encode_data(train_file, Vw, Vi)
    print(f"Nombre de phrases encodées : {len(encoded_train_data)}")

    # Étape 3 : Sauvegarder les vocabulaires
    save_vocab(Vw, Vi, "vocab")
    print("Vocabulaires sauvegardés dans le dossier 'vocab'.")
# Out:
# Taille du vocabulaire des mots (Vw) : 1443
# Taille du vocabulaire des étiquettes (Vi) : 18
# Nombre de phrases encodées : 1003
# Vocabulaires sauvegardés dans le dossier 'vocab'.

# %%
import torch
import torch.nn as nn

class POSTagger(nn.Module):
    def __init__(self, vocab_size, tagset_size, embedding_dim, hidden_dim, padding_idx=0, dropout=0.5):
        super(POSTagger, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=padding_idx)
        self.gru = nn.GRU(embedding_dim, hidden_dim, batch_first=True, bias=False)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim, tagset_size)

    def forward(self, x):
        # x de taille (batch_size, seq_len)
        embeds = self.embedding(x)  # (batch_size, seq_len, embedding_dim)
        gru_out, _ = self.gru(embeds)  # (batch_size, seq_len, hidden_dim)
        gru_out = self.dropout(gru_out)
        logits = self.fc(gru_out)  # (batch_size, seq_len, tagset_size)
        return logits

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset


# Création d'un Dataset personnalisé
class POSDataset(Dataset):
    def __init__(self, encoded_data):
        self.encoded_data = encoded_data

    def __len__(self):
        return len(self.encoded_data)

    def __getitem__(self, idx):
        return self.encoded_data[idx]

# Fonction de collate pour le DataLoader
def collate_fn(batch):
    words = [item[0] for item in batch]
    tags = [item[1] for item in batch]
    padded_words = pad_batch(words, pad_value=PAD_ID)
    padded_tags = pad_batch(tags, pad_value=PAD_ID)
    return padded_words, padded_tags

# Fonction d'entraînement sur une époque
def train(model, dataloader, criterion, optimizer, device):
    model.train()
    total_loss = 0.0
    for words, tags in dataloader:
        words = words.to(device)
        tags = tags.to(device)
        optimizer.zero_grad()
        outputs = model(words)  # (batch, seq, tagset_size)
        outputs = outputs.view(-1, outputs.shape[-1])
        tags = tags.view(-1)
        loss = criterion(outputs, tags)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(dataloader)

# Fonction d'évaluation sur le set dev
def evaluate(model, dataloader, criterion, device):
    model.eval()
    total_loss = 0.0
    correct = 0
    total_tokens = 0
    with torch.no_grad():
        for words, tags in dataloader:
            words = words.to(device)
            tags = tags.to(device)
            outputs = model(words)
            outputs = outputs.view(-1, outputs.shape[-1])
            tags = tags.view(-1)
            loss = criterion(outputs, tags)
            total_loss += loss.item()

            predictions = outputs.argmax(dim=1)
            mask = tags != PAD_ID
            correct += (predictions[mask] == tags[mask]).sum().item()
            total_tokens += mask.sum().item()
    accuracy = correct / total_tokens if total_tokens > 0 else 0
    return total_loss / len(dataloader), accuracy

if __name__ == "__main__":
    # Chemins vers les fichiers
    train_file = "/content/qaf_arabizi-ud-train.conllu"
    dev_file = "/content/qaf_arabizi-ud-dev.conllu"

    # Hyperparamètres
    embedding_dim = 100
    hidden_dim = 128
    batch_size = 32
    epochs = 10
    learning_rate = 0.001
    min_freq = 2
    dropout = 0.5
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Construction des vocabulaires à partir du fichier d'entraînement
    Vw, Vi = build_vocab(train_file, min_freq)
    print(f"Taille du vocabulaire des mots : {len(Vw)}")
    print(f"Taille du vocabulaire des étiquettes : {len(Vi)}")

    # Sauvegarde des vocabulaires
    save_vocab(Vw, Vi, "vocab")

    # Encodage des données d'entraînement et de développement
    train_data = encode_data(train_file, Vw, Vi)
    dev_data = encode_data(dev_file, Vw, Vi)

    train_dataset = POSDataset(train_data)
    dev_dataset = POSDataset(dev_data)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
    dev_loader = DataLoader(dev_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

    # Initialisation du modèle, de la fonction de perte et de l'optimiseur
    model = POSTagger(vocab_size=len(Vw), tagset_size=len(Vi),
                      embedding_dim=embedding_dim, hidden_dim=hidden_dim,
                      padding_idx=PAD_ID, dropout=dropout)
    model.to(device)

    criterion = nn.CrossEntropyLoss(ignore_index=PAD_ID)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Boucle d'entraînement
    for epoch in range(1, epochs+1):
        train_loss = train(model, train_loader, criterion, optimizer, device)
        dev_loss, dev_accuracy = evaluate(model, dev_loader, criterion, device)
        print(f"Epoch {epoch}: train loss = {train_loss:.4f}, dev loss = {dev_loss:.4f}, dev accuracy = {dev_accuracy:.4f}")

    # Sauvegarde du modèle et des paramètres nécessaires
    model_state = {
        'model_state_dict': model.state_dict(),
        'Vw': Vw,
        'Vi': Vi,
        'embedding_dim': embedding_dim,
        'hidden_dim': hidden_dim,
        'PAD_ID': PAD_ID,
        'UNK_ID': UNK_ID
    }
    torch.save(model_state, "pos_tagger.pt")
    print("Modèle sauvegardé dans pos_tagger.pt")
# Out:
# Taille du vocabulaire des mots : 1443
# Taille du vocabulaire des étiquettes : 18
# Epoch 1: train loss = 2.4798, dev loss = 2.1086, dev accuracy = 0.3822
# Epoch 2: train loss = 2.0280, dev loss = 1.8138, dev accuracy = 0.4623
# Epoch 3: train loss = 1.7729, dev loss = 1.6495, dev accuracy = 0.5147
# Epoch 4: train loss = 1.6054, dev loss = 1.5494, dev accuracy = 0.5403
# Epoch 5: train loss = 1.4968, dev loss = 1.4562, dev accuracy = 0.5778
# Epoch 6: train loss = 1.4049, dev loss = 1.3956, dev accuracy = 0.5901
# Epoch 7: train loss = 1.3271, dev loss = 1.3492, dev accuracy = 0.6114
# Epoch 8: train loss = 1.2723, dev loss = 1.3023, dev accuracy = 0.6216
# Epoch 9: train loss = 1.2101, dev loss = 1.2796, dev accuracy = 0.6319
# Epoch 10: train loss = 1.1620, dev loss = 1.2482, dev accuracy = 0.6412
# Modèle sauvegardé dans pos_tagger.pt

# %%
import torch
from conllu import parse_incr

def load_model(model_path, device):
    checkpoint = torch.load(model_path, map_location=device)
    Vw = checkpoint['Vw']
    Vi = checkpoint['Vi']
    embedding_dim = checkpoint['embedding_dim']
    hidden_dim = checkpoint['hidden_dim']
    model = POSTagger(vocab_size=len(Vw), tagset_size=len(Vi),
                      embedding_dim=embedding_dim, hidden_dim=hidden_dim,
                      padding_idx=PAD_ID)
    model.load_state_dict(checkpoint['model_state_dict'])
    model.to(device)
    model.eval()
    return model, Vw, Vi

def predict_sentence(model, sentence, Vw, Vi, device):
    # Extraction des mots et conversion en indices
    words = [token['form'].lower() for token in sentence]
    word_indices = [Vw.get(word, UNK_ID) for word in words]
    input_tensor = torch.tensor(word_indices, dtype=torch.long).unsqueeze(0).to(device)
    with torch.no_grad():
        outputs = model(input_tensor)  # (1, seq_len, tagset_size)
        predictions = outputs.argmax(dim=-1).squeeze(0).cpu().tolist()
    # Création d'un dictionnaire inverse pour les étiquettes
    rev_Vi = {idx: tag for tag, idx in Vi.items()}
    predicted_tags = [rev_Vi.get(idx, "UNK") for idx in predictions]
    return predicted_tags

if __name__ == "__main__":
    import sys
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model_path = "/content/pos_tagger.pt"

    # Chargement du modèle et des vocabulaires
    model, Vw, Vi = load_model(model_path, device)

    # Chemin du fichier à traiter (par exemple dev ou test)
    file_path = "/content/qaf_arabizi-ud-test.conllu"

    with open(file_path, "r", encoding="utf-8") as f:
        for sentence in parse_incr(f):
            predicted_tags = predict_sentence(model, sentence, Vw, Vi, device)
            tokens = [token["form"] for token in sentence]
            print("Sentence :", " ".join(tokens))
            print("Predicted POS :", " ".join(predicted_tags))
            print("---")
# Out:
# <ipython-input-8-b68e48d3da73>:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# Sentence : amina2003alg@yahoofr
# Predicted POS : VERB
# ---
# Sentence : eh benh man jadda wadjad wa man zara3a hassad elli ta3bo nchalah enajah e najah w lokhrine l okhrine mel m el ahsane esanw
# Predicted POS : VERB VERB PRON VERB VERB CCONJ PRON VERB VERB VERB VERB INTJ VERB DET NOUN CCONJ VERB DET NOUN _ ADP DET NOUN VERB
# ---
# Sentence : ntouma ma3labalkomch ja bladna director general ta3 cannal+ ewa appres ki masha 3la alger chaf danya ka3 barabollat alors f conference m3a press 9alhoum algerie champion du monde f barabol ? chafto kifach tbahdila wallah hada li dar 9anoun ya3tih saha bazaf ? ness tabki parce wue khlas ya y a pas xxxx amcho tobo ila allah allah yahdina wa iyakom amin ya rabi
# Predicted POS : PRON VERB VERB NOUN VERB VERB ADP NOUN VERB VERB ADV VERB ADP NOUN VERB VERB VERB VERB VERB ADP NOUN ADP NOUN _ PROPN ADP ADP NOUN ADP NOUN PUNCT VERB ADV NOUN INTJ PRON PRON VERB NOUN VERB NOUN DET PUNCT PRON VERB VERB VERB VERB INTJ PRON VERB ADV VERB VERB VERB ADP PROPN PROPN VERB CCONJ VERB INTJ INTJ PROPN
# ---
# Sentence : il a raison puisque la venir dyalo avant tout yjiboh yel3ab un matche et yhawzoh
# Predicted POS : PRON DET PROPN SCONJ DET NOUN VERB PRON PRON VERB PRON DET NOUN CCONJ VERB
# ---
# Sentence : 7atoh f sachie o b3et tayech l al be7ar
# Predicted POS : VERB ADP NOUN CCONJ VERB VERB DET DET NOUN
# ---
# Sentence : in challah saifi ayder hadja ma3a el farik el watani
# Predicted POS : DET VERB PRON VERB VERB ADP DET NOUN DET NOUN
# ---
# Sentence : allah yahafdak w ykhalika lina ya Mr le président w tahia bouteflika w rana m3ak
# Predicted POS : PROPN VERB CCONJ VERB PRON INTJ PROPN DET NOUN CCONJ VERB PRON CCONJ VERB PRON
# ---
# Sentence : c aussi notre responsabilité kom musulmans samehna 3ami mohamed pour le mal ki t arriwe
# Predicted POS : VERB ADV DET NOUN VERB VERB VERB NOUN NOUN ADP DET NOUN ADV VERB VERB
# ---
# Sentence : bn courage matmoure w nchalah njibouha w rabi m3akom
# Predicted POS : VERB NOUN VERB CCONJ INTJ VERB CCONJ PROPN PRON
# ---
# Sentence : walah yrid messi rah yal3ab m3a ziani
# Predicted POS : INTJ VERB ADP VERB VERB ADP PROPN
# ---
# Sentence : me3ak ya hamiti ou li sar isir vive la jsimazighen
# Predicted POS : PRON INTJ PROPN CCONJ PRON VERB VERB VERB DET NOUN
# ---
# Sentence : wa len tarda 3aleyka el yahoud wa la el nassara hata tatabi3a milatahoum
# Predicted POS : CCONJ VERB VERB VERB DET NOUN CCONJ PART DET NOUN ADP NOUN VERB
# ---
# Sentence : allez les fenecs rabi m3akoum
# Predicted POS : VERB DET NOUN PROPN PRON
# ---
# Sentence : koul 3andkoum hak ya shab les commentaire
# Predicted POS : PRON VERB PRON INTJ NOUN DET NOUN
# ---
# Sentence : allah yaj3alha takhfif edounoub e dounoub wellah w ellah ychafik
# Predicted POS : PROPN VERB VERB VERB DET NOUN INTJ CCONJ VERB VERB
# ---
# Sentence : s7aybi chkoun ana ? lotfi double kanon
# Predicted POS : VERB PRON PRON PUNCT VERB NOUN VERB
# ---
# Sentence : anchalah on va gagner 1 / 0 bezaf 3lina chnana fi 3adyan 123 viva l'algerie l' algerie
# Predicted POS : VERB PRON VERB VERB NUM PUNCT NUM ADV PRON VERB ADP NOUN INTJ VERB _ DET PROPN
# ---
# Sentence : ya3arfou ghir halane el foum bye bye algeria merci saadane
# Predicted POS : DET PART VERB DET NOUN INTJ VERB ADV INTJ PROPN
# ---
# Sentence : Kayen ghâchi fel'matar f el' matar , kayen ghachi f les bars , fechwara3 fe chwara3 k les barbares
# Predicted POS : VERB VERB VERB ADP NOUN VERB PUNCT VERB VERB ADP DET NOUN PUNCT VERB ADP NOUN PROPN DET NOUN
# ---
# Sentence : 123 vive l'algerie l' algerie et le maroc inchalah lil3ab li l3ab mazyan nssaf9o lo
# Predicted POS : INTJ VERB _ DET PROPN CCONJ DET PROPN INTJ NOUN PRON VERB VERB VERB VERB
# ---
# Sentence : Bjr et bravo pr cet femme là et que dieu accepte sa omra inchallah elle est vriment courageuse rabi é koune m3aha
# Predicted POS : VERB CCONJ INTJ NOUN NOUN VERB VERB CCONJ SCONJ PROPN VERB PRON VERB INTJ DET VERB VERB VERB PROPN VERB VERB PRON
# ---
# Sentence : m3ak ya lkhadra l khadra rabhine wala khasrine mouhime charaftouna 123 vive lalgerie l algerie
# Predicted POS : PRON INTJ PROPN DET PROPN VERB CCONJ VERB VERB VERB INTJ VERB _ DET PROPN
# ---
# Sentence : Kount qder na3fes 3la galbi w nrouh nasréq
# Predicted POS : ADV VERB VERB ADP NOUN CCONJ VERB VERB
# ---
# Sentence : il falait remercie tout d'adord d' adord ALLAH avant de ringuauler elhadoullillah 3ala ni3matb elamen el amen
# Predicted POS : PRON VERB VERB PRON VERB ADP NOUN PROPN PRON ADP VERB VERB ADP NOUN VERB DET NOUN
# ---
# Sentence : o men ba3d yero7 yefsakhe al fat7a
# Predicted POS : CCONJ ADP VERB VERB VERB DET NOUN
# ---
# Sentence : farik te3 dberech 3ando des supportuer dberech
# Predicted POS : VERB VERB VERB ADV DET NOUN VERB
# ---
# Sentence : allah ghaleb c tous ki nous reste !!! wa3leche ihoufouna makan lakhedma la khedma lat3ame!!!!allah la t3ame !!!! allah yehdii houkoumttna
# Predicted POS : PROPN PROPN VERB PRON ADV PRON VERB PRON VERB VERB VERB VERB DET NOUN VERB DET NOUN PUNCT PROPN VERB VERB
# ---
# Sentence : rah 3andana amal kbir ftaahol f taahol wntmana w ntmana nkono lmotaahil l motaahil 1 w maroc le milleur 2eme bach ntal3o 7na wyahom w yahom nchalah bonn chonce
# Predicted POS : VERB VERB VERB PRON VERB ADP NOUN VERB CCONJ VERB VERB VERB DET NOUN INTJ CCONJ PROPN DET NOUN VERB ADP VERB PRON NOUN CCONJ VERB INTJ VERB VERB
# ---
# Sentence : nchalah 3a9ba la victoire contre zambia
# Predicted POS : INTJ VERB DET NOUN ADP PROPN
# ---
# Sentence : wech men tawra jayin tgoulo 3liha makan la tawra la kosbor la ma3adnouss
# Predicted POS : PROPN ADP VERB VERB VERB PRON VERB DET NOUN PART NOUN PART NOUN
# ---
# Sentence : teghidni tefla l jamais sme3na baha
# Predicted POS : VERB ADV DET NOUN VERB VERB
# ---
# Sentence : yketlouna kif ma3toub wla yanfiwna men leblad le blad
# Predicted POS : VERB ADV VERB ADV VERB ADP _ DET NOUN
# ---
# Sentence : 3amrousse nous avec la stabilté du club merci
# Predicted POS : VERB PRON ADP DET NOUN ADP NOUN INTJ
# ---
# Sentence : el wihda chi3arouna
# Predicted POS : DET NOUN VERB
# ---
# Sentence : le numero 4 la yougharid kharij esserb e sserb rapelle toi seddam et l eglise a katar et ley et tu pense que madjliss el 3ar a raison et tu pense que el djazira ni pas fitna el kaddafi et son peuple el bar
# Predicted POS : DET NOUN ADP DET NOUN VERB VERB DET NOUN VERB PRON VERB CCONJ DET NOUN ADP NOUN CCONJ VERB CCONJ PRON VERB SCONJ VERB DET NOUN ADP NOUN CCONJ PRON VERB SCONJ DET NOUN ADV ADV VERB DET NOUN CCONJ INTJ NOUN DET NOUN
# ---
# Sentence : c'est c' est noael c'est c' est pour ça emmmmmmm mlih 3aido apré nahkom 3lih
# Predicted POS : _ PRON VERB VERB _ PRON VERB ADP PRON VERB PRON VERB VERB VERB PRON
# ---
# Sentence : alihada assabab a ssabab kanat touwakafou el bakhirat limoudatin li moudatin tawila fi el mawani bach idjiboulna sebbat el bay3 hakada houm el djazairiyoun ki yessam3ou wahed 3erbi ikounou ta3matelhoum mouslim kana bilimkan bi l imkan woudjoud houloul oukhra douna el bay3 ya dra loukan n'koul ana 3arbiya wach imedouli yakhi yakh
# Predicted POS : VERB VERB DET NOUN VERB VERB DET NOUN VERB PRON VERB VERB ADP DET NOUN ADP VERB VERB DET NOUN VERB PRON DET NOUN ADV VERB NOUN VERB VERB VERB VERB PRON VERB ADP DET NOUN VERB VERB VERB VERB DET NOUN INTJ NOUN PRON VERB PRON ADJ PRON VERB INTJ VERB
# ---
# Sentence : wach edakoum tbi3ou les matches ta3 l'équipe l' équipe national ma 3andna ni chaine de sport ni télévision msegam
# Predicted POS : PRON VERB VERB DET NOUN ADP _ DET NOUN ADJ PART PRON VERB VERB ADP NOUN NOUN VERB VERB
# ---
# Sentence : lazam asha3b a sha3b inodh daoula islamya la la la lihizb li hizb firanssa tahya aljazair al jazair tahya almarroc al marroc tahya tousnes asaghira a saghira al3adhima al 3adhima
# Predicted POS : VERB VERB DET NOUN VERB VERB VERB DET DET DET NOUN PRON VERB VERB ADP NOUN DET PROPN ADV NOUN DET NOUN ADP NOUN VERB DET NOUN VERB DET NOUN
# ---
# Sentence : dima isti3ana b lmgharba l mgharba f jami3 lmajalat l majalat lol
# Predicted POS : ADV VERB ADP NOUN DET NOUN ADP NOUN NOUN DET NOUN PRON
# ---
# Sentence : akhdem dwa barka bla la3ab bness b ness
# Predicted POS : VERB VERB VERB VERB NOUN VERB ADP NOUN
# ---
# Sentence : hadi d3awi khalifa
# Predicted POS : PRON VERB PRON
# ---
# Sentence : m3ak ya bladi rabhin wella khasrine
# Predicted POS : PRON INTJ PROPN VERB CCONJ VERB
# ---
# Sentence : saraha ma3andna man9olo f nos freres algerien tbark lah 3likom
# Predicted POS : VERB VERB VERB ADP DET NOUN NOUN VERB PROPN PRON
# ---
# Sentence : 1 2 3 vive algerian ;3ak ya rezki bey
# Predicted POS : INTJ INTJ INTJ VERB PROPN VERB INTJ NOUN VERB
# ---
# Sentence : makach ballon f dzayer barka ma tkhaltou 3lina normalement drahem li rahoum yaklou fihom les joueurs ( mssaken ) ya3touhom les jeunes ( hommes ) rakoum 3labalkoum kechma yekhdmou 3la rwah om lhala l hala rahi ri tzid tes3ab allah yjib lkhir l khir
# Predicted POS : NUM VERB ADP PROPN VERB PART VERB PRON PRON NOUN PRON VERB VERB PRON DET NOUN PUNCT VERB PUNCT VERB DET NOUN PUNCT VERB PUNCT VERB VERB VERB VERB ADP NOUN VERB VERB DET NOUN VERB NOUN VERB VERB PROPN VERB NOUN DET NOUN
# ---
# Sentence : Hadi c'est c' est normal un juif 3andou facebook parce - que 24h/24 24 h / 24 ya9ra ou yet3alem
# Predicted POS : PRON _ PRON VERB ADV DET NOUN NOUN VERB VERB PUNCT SCONJ VERB VERB VERB PUNCT VERB VERB CCONJ VERB
# ---
# Sentence : hakda les algerien w inchalah coup du monde w sa3dan lazmek t3aet 3la jabour
# Predicted POS : INTJ DET NOUN CCONJ INTJ ADV ADP NOUN CCONJ PROPN VERB VERB ADP NOUN
# ---
# Sentence : Kif li yesreq jarou ki ychoufou rah fi voyage
# Predicted POS : ADV PRON VERB VERB ADV VERB VERB ADP NOUN
# ---
# Sentence : kol youm 3andak jadide
# Predicted POS : DET NOUN PRON VERB
# ---
# Sentence : rabi yastar m3a english ou marican
# Predicted POS : PROPN VERB ADP NOUN CCONJ VERB
# ---
# Sentence : non rak ghalat rafik saifi mazawdj ou 3andou tafal
# Predicted POS : INTJ VERB VERB ADP PROPN VERB CCONJ PRON VERB
# ---
# Sentence : rabi m3akome ila hatmcho bnayatkome parce que mol nia yatla3 ki la3lame la 3lame allez les verts bonne chance rabi m3akom w rana m3akom jusqu'à la mort
# Predicted POS : PROPN VERB ADP VERB NOUN VERB SCONJ VERB VERB VERB ADV VERB DET NOUN VERB DET NOUN ADJ NOUN PROPN PRON CCONJ VERB PRON VERB DET NOUN
# ---
# Sentence : alah ysahelkoum nchllh w rabi m3akoum w maykoun ghi lkhir l khir nchallh bon chance pour tt le monde
# Predicted POS : PROPN VERB VERB CCONJ PROPN PRON CCONJ VERB PRON VERB DET NOUN VERB ADJ NOUN ADP NOUN DET NOUN
# ---
# Sentence : hsbiya lah wa ni3ma wakil fi dawlatina nkifach sayfi ta3tolo melyar ou hada meskin ma3andoch bach yachri khobza anchalah yakhsroga3 yakhsro ga3 li match
# Predicted POS : VERB PROPN CCONJ NOUN NOUN ADP NOUN VERB VERB VERB VERB CCONJ PRON NOUN VERB ADP VERB VERB VERB VERB VERB ADV PRON VERB
# ---
# Sentence : salem inchaallah farikna yarbah wa nekoll lsaadane l saadane lazamlkom rokya hadi matekoune raire 3aine elhasdine el hasdine
# Predicted POS : PROPN VERB VERB VERB CCONJ VERB VERB DET PROPN VERB VERB PRON VERB NOUN VERB VERB DET NOUN
# ---
# Sentence : Ratteb qaanoun al ousra , tant pie lyoum l youm rej3et 7ourra , jm'en j m' en fou ana mzewwaj 3achra
# Predicted POS : VERB VERB DET NOUN PUNCT VERB VERB VERB DET NOUN VERB VERB PUNCT VERB PRON PRON ADP VERB PRON VERB VERB
# ---
# Sentence : Rabi y3awen kawetna twanssa rana net3almou menkoum
# Predicted POS : PROPN VERB VERB VERB VERB VERB VERB
# ---
# Sentence : 3andou wach shih hada Lamouchia ca cerai bien qi'il qi' il retourne au bled
# Predicted POS : PRON PRON VERB PRON NOUN PRON VERB ADV VERB VERB PRON VERB ADP NOUN
# ---
# Sentence : had el3am el 3am ma3nda matetmch elnehd el elnehd
# Predicted POS : PRON PRON DET NOUN VERB NOUN VERB DET NOUN
# ---
# Sentence : la la yastahel sa3dan m3ak dima 123 viva l'algerie l' algerie
# Predicted POS : DET DET NOUN PROPN PRON ADV INTJ VERB _ DET PROPN
# ---
# Sentence : rabi yedj3al had el 3am 3am khir 3ala el djazair Ya rabi
# Predicted POS : PROPN VERB PRON DET NOUN NOUN NOUN ADP DET NOUN INTJ PROPN
# ---
# Sentence : vive l'algerie l' algerie rana m3akoum ya moharibiy sahraa ya afnak m3ak ya lkhadra l khadra m3ak ya dzayer diri hala
# Predicted POS : VERB _ DET PROPN VERB PRON INTJ NOUN VERB INTJ NOUN PRON INTJ NOUN DET PROPN PRON INTJ PROPN VERB NOUN
# ---
# Sentence : W ana nmout meta3dib wra mandir i3tirafat
# Predicted POS : CCONJ PRON VERB VERB ADP VERB VERB
# ---
# Sentence : vive mca w nchalah had l'3am l' 3am championi
# Predicted POS : VERB PROPN CCONJ INTJ PRON VERB DET NOUN ADV
# ---
# Sentence : album jdid fih soufrance ta3 nass
# Predicted POS : VERB VERB PRON VERB ADP NOUN
# ---
# Sentence : Un grand merci pour cette équipe de sétif l3ali l 3ali et je les souhaite beaucoup plus de succès
# Predicted POS : DET NOUN INTJ ADP DET NOUN ADP NOUN CCONJ DET NOUN CCONJ PRON DET NOUN ADV ADV ADP NOUN
# ---
# Sentence : elah yarhem dhahaya el irhab el hamadji ha dhou houma erdjal e rdjal fi beladi ahhhhhh b elahra el ahra 3and boutef je pose un simple question est ce que un couchon comme ce la il peut vivre avec nous dans notre societe ????? welahi manamenkoume ila goltou oui par ce que la solution d'extermine d' extermine hadhou el mahkloukate
# Predicted POS : INTJ VERB VERB DET NOUN DET NOUN VERB NOUN PRON VERB DET NOUN ADP NOUN VERB ADP NOUN DET NOUN ADP PROPN PRON VERB DET NOUN VERB VERB DET SCONJ DET NOUN PRON DET DET NOUN PRON VERB ADP PRON ADP DET NOUN VERB VERB VERB ADP VERB ADP VERB DET SCONJ DET NOUN VERB ADP NOUN VERB DET NOUN
# ---
# Sentence : Ki nesma3 b satellite , w dzayer khadmet zalamet w tetfarqa3 ki dinamit
# Predicted POS : ADV ADV ADP NOUN PUNCT CCONJ VERB VERB VERB CCONJ VERB ADV VERB
# ---
# Sentence : mlih yal3ab w klhalouna min hadra fargha hada wach na3arfou bark ghir hadra rahi batal salam vive l´algerie l´ algerie
# Predicted POS : PRON VERB CCONJ VERB ADP NOUN VERB PRON PRON VERB ADV PART NOUN VERB NOUN INTJ VERB PROPN VERB PROPN
# ---
# Sentence : Allahouma achfi akhana rayane Allahouma khafif anhou Allahouma zidhou sabran Allahouma arziqhou el kafa oua al 3affaf Allahouma arzouq ahlahou al sebr Allahouma 3adjil bi chiffaihi
# Predicted POS : ADJ VERB VERB VERB ADJ VERB VERB ADJ VERB VERB ADJ VERB DET NOUN CCONJ DET NOUN ADJ VERB VERB DET NOUN ADJ VERB ADP NOUN
# ---
# Sentence : nchoufo wach te3mel biha ya ben chikha m3a mahaliyin
# Predicted POS : VERB PRON VERB PRON INTJ PROPN VERB ADP NOUN
# ---
# Sentence : alhe yarhamha oi ya g3alha mina al moaminine oi mine ashabe al janhe
# Predicted POS : VERB VERB VERB INTJ NOUN ADP DET NOUN VERB ADP NOUN DET NOUN
# ---
# Sentence : rabi m3ana
# Predicted POS : PROPN PRON
# ---
# Sentence : rouh ya habibo nchallah rabi ykoun m3ak 123 viva la algerie
# Predicted POS : INTJ INTJ PROPN INTJ PROPN VERB PRON INTJ VERB DET PROPN
# ---
# Sentence : vive usman et vive m3aiza
# Predicted POS : VERB PROPN CCONJ VERB PROPN
# ---
# Sentence : hado homa rajala mojahidon vive hamas kataeb lkasam we kol lmokawama l mokawama ana tmenit nkon njahed m3ahom
# Predicted POS : PRON PRON PRON VERB VERB PROPN VERB VERB CCONJ DET NOUN DET NOUN PRON VERB VERB VERB PRON
# ---
# Sentence : rouhi ya bladi rouhi beslama b e slama c honteux les responssables nt3a albackss
# Predicted POS : VERB INTJ PROPN VERB VERB ADP DET NOUN VERB VERB DET NOUN VERB VERB
# ---
# Sentence : 3andi koleche sofe l'expéreonce l' expéreonce
# Predicted POS : PRON VERB VERB VERB DET NOUN
# ---
# Sentence : viva l'algirie l' algirie nchalah ya rabi rana rabhin ranna m3akom
# Predicted POS : VERB VERB DET NOUN INTJ INTJ PROPN VERB VERB VERB PRON
# ---
# Sentence : Tqoulchi khlassou rjal rmawna kamel f la poubelles ; wach 3melna f isteqlal
# Predicted POS : VERB VERB PRON VERB NOUN ADP DET NOUN PUNCT PRON VERB ADP NOUN
# ---
# Sentence : bnj lamouchia sa place est dans real madrid pas zamalek et m3ak ya khadra et vive ASO w mazel MCO
# Predicted POS : VERB VERB PRON VERB VERB ADP VERB VERB ADV VERB CCONJ PRON INTJ PROPN CCONJ VERB PROPN CCONJ VERB PROPN
# ---
# Sentence : na9ra 3liha sora o nzid nemas
# Predicted POS : VERB PRON VERB CCONJ VERB VERB
# ---
# Sentence : Koun dkhalt f had el domaine ndir charika b ras el mal
# Predicted POS : VERB VERB ADP PRON DET NOUN VERB VERB ADP NOUN DET NOUN
# ---
# Sentence : hna fi la pharmacie kan 3adna ghi vendredi raha ki zadona samdi baghé yagla3ha
# Predicted POS : PRON ADP DET NOUN VERB PRON PRON VERB VERB ADV VERB VERB VERB VERB
# ---
# Sentence : madam 3andna sa3dan wa ziani et bezaz w el hadj
# Predicted POS : VERB PRON PROPN CCONJ PROPN CCONJ VERB CCONJ DET NOUN
# ---
# Sentence : Fi cent mille salariés talla3 gadah rbaht
# Predicted POS : ADP NOUN NOUN VERB VERB VERB VERB
# ---
# Sentence : Mabrook algeria et mabrook maroc 3antlakaw incha allah tani f marakkech
# Predicted POS : VERB ADV CCONJ VERB PROPN VERB PROPN PROPN VERB ADP NOUN
# ---
# Sentence : blasto mafihach hadra surtout ki mayal3abch bezzaz
# Predicted POS : VERB VERB PROPN PRON ADV VERB VERB
# ---
# Sentence : toutes mes félicitation à toi karim rabbi nchallah yaslahlek fiha w yarzkak dhorya alssalha al ssalha w ywafkek amine ya rabbi l3alamine l 3alamine
# Predicted POS : ADJ DET NOUN ADP PRON PROPN VERB INTJ VERB PRON CCONJ VERB VERB VERB DET NOUN CCONJ VERB INTJ INTJ PROPN VERB DET NOUN
# ---
# Sentence : desole ilham mes vive el gawriyat ki natzawdjo bikoum tkarhoma fi yamana ou khiyatna ou familatna hadi hakika adiro el plon w anhass a nhass w el3akar el 3akar ntoma asamhili asamhi li wa lakin wa3rin bazef HACHA ALI MATASTAHELCH 10POUR100 10 POUR100 YASALHO W ELBAKI EL BAKI CHOKH BLA MOKH
# Predicted POS : VERB VERB DET VERB DET NOUN ADV VERB VERB VERB ADP NOUN CCONJ VERB CCONJ VERB PRON VERB NOUN DET NOUN CCONJ VERB DET NOUN CCONJ VERB DET NOUN ADV NOUN VERB PRON CCONJ PRON VERB ADV NOUN PRON VERB VERB VERB VERB VERB CCONJ VERB DET NOUN VERB VERB NOUN
# ---
# Sentence : Qoulli wachen had la 7iyat , ya7akmou fina l madammat , ya7akmou fina l maddamat
# Predicted POS : INTJ VERB PRON DET NOUN PUNCT VERB PRON DET NOUN PUNCT VERB PRON DET NOUN
# ---
# Sentence : al iman w e saber hiya le7wayej le 7wayej li 7atnejik
# Predicted POS : DET NOUN CCONJ DET NOUN PRON VERB DET NOUN PRON VERB
# ---
# Sentence : ellahoma ahdina w e3fo 3ana
# Predicted POS : VERB VERB CCONJ VERB VERB
# ---
# Sentence : la hawla wa la 9ouata illa billeh bi lleh el 3alii l'3adhim l' 3adhim à un moment donné j'ai j' ai crus que je lis un roman dramatique malheureusement la réalité est plus dramatique que l'on l' on puisse imaginer allah yahdina w yechfi les petites RABI KBIR
# Predicted POS : DET NOUN CCONJ PART NOUN PART VERB ADP NOUN DET NOUN VERB DET NOUN ADP DET NOUN VERB VERB PRON VERB VERB SCONJ PRON VERB DET NOUN VERB VERB DET NOUN VERB ADV VERB SCONJ VERB DET NOUN VERB VERB PROPN VERB CCONJ VERB DET NOUN PROPN VERB
# ---
# Sentence : merci mazal inchalah m3a angola
# Predicted POS : INTJ ADV INTJ ADP PROPN
# ---
# Sentence : l chekon 7atecheki , la famille makanlhache , l s7abatha matelgache o jiran madekhalnache
# Predicted POS : DET NOUN VERB PUNCT DET NOUN VERB PUNCT DET NOUN VERB CCONJ VERB NOUN
# ---
# Sentence : vive toi magik rabi m3ak
# Predicted POS : VERB PRON NOUN PROPN PRON
# ---
# Sentence : vive chyoukha siadna dima m3akoum
# Predicted POS : VERB PROPN VERB ADV PRON
# ---
# Sentence : oui mazal 3ayeche et mieu que toi meme vous ete en algerie ma cher mira
# Predicted POS : INTJ ADV VERB CCONJ ADV SCONJ PRON ADV PRON VERB ADP PROPN PART VERB VERB
# ---
# Sentence : mlih algerie ki hakmat khayn kbir semouh alhaycha psq kan haghar dahayah bzf kan ykhalas almanouvria al manouvria 500 da wana wa na khdamt 3andah
# Predicted POS : PRON PROPN ADV VERB VERB PRON VERB VERB VERB VERB VERB VERB VERB VERB VERB VERB DET NOUN VERB ADV VERB CCONJ VERB VERB VERB
# ---
# Sentence : rabi ykoun m3ahoum nchallah c la vie
# Predicted POS : PROPN VERB PRON INTJ VERB DET NOUN
# ---
# Sentence : Ki nchouf télévision kayen la greve des enseignants yezguiw lhouym l houym les fainéants
# Predicted POS : ADV VERB VERB VERB DET NOUN DET NOUN VERB VERB DET NOUN DET NOUN
# ---
# Sentence : saadan ye3ref ghir la defense n7awsou entrineur yel3ab bach yerba7 merci saadane mais lazem trou7
# Predicted POS : PROPN VERB PART DET NOUN VERB VERB PRON ADP VERB INTJ PROPN CCONJ VERB VERB
# ---
# Sentence : m3aya wlad cha3b wlad zwawawawla
# Predicted POS : PRON PRON NOUN VERB VERB
# ---
# Sentence : makanech menha choufoulina une autre histoire la securite dyalna ma kedrouch hata ye3arfou les teroristes de lecole l ecole de yesser o yejou yekhorto 3alina avec une histoire a la haute niveau
# Predicted POS : INTJ NOUN VERB DET NOUN _ DET NOUN VERB PART VERB ADP NOUN DET NOUN ADP NOUN DET NOUN ADP NOUN CCONJ VERB VERB VERB ADP DET PROPN DET DET NOUN VERB
# ---
# Sentence : حجج حجج حجج حجج حجج حجج comme il a dit n
# Predicted POS : VERB VERB VERB VERB VERB VERB PRON PRON VERB ADV NOUN
# ---
# Sentence : ya wedi ta3arfou ghir tebkou yaw fakou dourk el-azhar el- azhar eykheredj fetwa sur mesure bache terebhou bessif be ssif aaaaaaaaaa
# Predicted POS : INTJ PROPN ADP PART VERB INTJ NOUN VERB VERB VERB VERB VERB VERB ADV NOUN PROPN VERB VERB ADP NOUN VERB
# ---
# Sentence : lyoum l youm ana howa li ra7 nekaser les tabous
# Predicted POS : INTJ DET NOUN PRON PRON PRON VERB VERB DET NOUN
# ---
# Sentence : nhab bladi w dima lalgerie l algerie w makra fl f l 3adyan
# Predicted POS : VERB PROPN CCONJ ADV _ DET PROPN CCONJ ADV VERB ADP DET NOUN
# ---
# Sentence : inchalah tel3a lel pac skara fel f el cab vive les algerois khawa khawa skara fi brawiales vont onvahir 20 aout nchalah
# Predicted POS : INTJ VERB _ VERB VERB _ ADP DET NOUN VERB DET NOUN VERB VERB VERB ADP NOUN VERB VERB VERB VERB INTJ
# ---
# Sentence : mabrouk 3lina w merci lal l al kahla li raha mtal3atana rassana
# Predicted POS : INTJ PRON CCONJ INTJ VERB DET DET NOUN PRON VERB VERB VERB
# ---
# Sentence : hada makanch liy3alak li y3alak 3lih yak loukane match nta3 liyedou les miliards ga3 tehadrou besah hada guelil
# Predicted POS : PRON NOUN VERB PRON VERB PRON PRON VERB NOUN ADP NOUN DET NOUN ADV VERB CCONJ PRON NOUN
# ---
# Sentence : nchalah neabho w njoo et en plus ntiho m3a egypt nchalah ya rabi
# Predicted POS : INTJ VERB CCONJ VERB CCONJ ADP ADV VERB ADP PROPN INTJ INTJ PROPN
# ---
# Sentence : ichouf tofla 3aîcha fi 3ezz weldiha même à l'âge l' âge de 30 ans >> ya3jbou el islam
# Predicted POS : VERB VERB VERB ADP NOUN VERB ADV ADP NOUN DET NOUN ADP NOUN NOUN VERB VERB DET NOUN
# ---
# Sentence : Nnas kherjet mel m el orbite , w 7na mazel bidoun zit , ana kraht ana mellit
# Predicted POS : VERB VERB _ ADP DET NOUN PUNCT CCONJ VERB VERB VERB VERB PUNCT PRON VERB PRON VERB
# ---
# Sentence : ram yontriniw kol youm 3a les agression2-de7*la rah tkoun kopa fawda3 - 3rak b mess w cha3b f stade
# Predicted POS : VERB VERB DET NOUN NOUN DET NOUN VERB PRON VERB VERB PUNCT VERB ADP NOUN CCONJ NOUN ADP NOUN
# ---
# Sentence : salam 3ala beladi salam 3alikome ya li rakome te3adiwe fi bac sur tou programe legdime le gdime helilekome hagrokoume mahatouche kaherabaee en plus le onec hate la correction ta3e jedide wa khala lgdime l gdime yemoute belkounta b el kounta rabi yahedik ya boubaker ben bouzid we 3erame 3elik 3and rabi hassebena allah wa ne3ema wakille
# Predicted POS : INTJ ADP NOUN INTJ NOUN INTJ PRON VERB VERB ADP NOUN ADV VERB VERB VERB DET NOUN VERB VERB VERB VERB ADP ADV DET NOUN VERB DET NOUN VERB VERB CCONJ VERB VERB DET NOUN VERB VERB ADP DET NOUN PROPN VERB INTJ NOUN PROPN PROPN CCONJ VERB VERB ADP PROPN VERB PROPN CCONJ VERB VERB
# ---
# Sentence : bismi bi smi elah wa lahou akbar alahouma ounsour ekwanana fi gaza alhouma damir elyahoud el yahoud wa man ma3ahoum alahouma damir amreka alahouma ehdi hokama el mouslimine wa sadide raayahoum
# Predicted POS : VERB ADP NOUN PRON CCONJ PRON VERB PROPN VERB VERB ADP NOUN VERB VERB ADP DET NOUN CCONJ ADP VERB PROPN VERB VERB PROPN VERB VERB DET NOUN CCONJ VERB VERB
# ---
# Sentence : Kount qader ndirha bessah ana ma derthach
# Predicted POS : ADV VERB VERB VERB PRON PART VERB
# ---
# Sentence : ma etwalich edir rajelk wa 3ichi m3aha fi canada raki etji tadfni ro7k han
# Predicted POS : PART VERB VERB VERB CCONJ VERB PRON ADP NOUN VERB VERB NOUN VERB VERB
# ---
# Sentence : Khafoo rabi ya djma3a rakoom bahdeltoona par tout
# Predicted POS : VERB PROPN INTJ NOUN VERB VERB VERB PRON
# ---
# Sentence : rana m3akom malgré tout 123 viva l'algerie l' algerie ya3tikom elsaha el saha ya les jeunes
# Predicted POS : VERB PRON PROPN PRON INTJ VERB _ DET PROPN VERB VERB DET NOUN INTJ DET NOUN
# ---
# Sentence : salam y'a ech-chourouk ch3ab krah c'est c' est pas la peine de le driblé dans sa tete une barque via l'europe l' europe
# Predicted POS : INTJ NOUN VERB VERB VERB _ PRON VERB ADV DET NOUN ADP DET NOUN ADP PRON VERB DET NOUN VERB VERB DET NOUN
# ---
# Sentence : ya rabi ya allah koun m3ana inchallah rana fi mondiale 2010 toujour l'algerie l' algerie mon amour
# Predicted POS : INTJ PROPN INTJ PROPN VERB PRON INTJ VERB ADP NOUN PROPN ADJ _ DET PROPN DET NOUN
# ---
# Sentence : vive l'algerie l' algerie ma3andna walou ghir rabi soub7ane
# Predicted POS : VERB _ DET PROPN VERB PRON PART PROPN VERB
# ---
# Sentence : rwahi lbadak l lbadak le maroc anti oe wladak ta3ichi rasak marfo3 fblad f blad alhoriya al horiya wa dimokrateya hadak alkadafi satakoun nihayatoho fi kotob atarikh a tarikh alhadit al hadit la3nato allah 3alieh oe wlidak allah eyrahmo oe eywasa3 3lieh tahiyati licha3b li cha3b libi wa jazairi
# Predicted POS : VERB VERB DET NOUN DET PROPN VERB VERB VERB VERB VERB VERB VERB ADP NOUN VERB DET NOUN CCONJ NOUN PRON VERB VERB VERB ADP NOUN VERB DET NOUN VERB DET NOUN VERB PROPN VERB VERB VERB PROPN VERB VERB VERB VERB VERB VERB PRON VERB VERB CCONJ VERB
# ---
# Sentence : Soubhan ALLAH el mousta3an Rabi yahfadhoum amine avez vous oublié que vous allez faire face à notre créateur et rendre compte de vos actes ?
# Predicted POS : VERB PROPN DET NOUN PROPN VERB INTJ VERB PRON VERB SCONJ PRON VERB ADP NOUN ADP DET NOUN CCONJ VERB ADP ADP DET NOUN PUNCT
# ---
# Sentence : yaw 3andhom el hak !! tjouz 3la salembier plus précisament 3la diar el mahssol smahli kho mais loukan tjib m3ak 3ayar \
# Predicted POS : INTJ VERB DET NOUN PUNCT VERB ADP NOUN ADV VERB ADP NOUN DET NOUN VERB NOUN CCONJ PRON VERB PRON VERB PRON
# ---
# Sentence : rabi m3ak khouya on te souhaite tte la réussite inchalah
# Predicted POS : PROPN PRON VERB PRON PRON VERB NOUN DET NOUN INTJ
# ---
# Sentence : salam saha ftourkom a tous allah m3akom ya rdjala tahya eldjzair el djzair ya matmour ya messi de l'algérie l' algérie inchallah elmondiale el mondiale et elbarca el barca pour toiu matmour tahya ga33 les 'algérien
# Predicted POS : INTJ INTJ NOUN DET NOUN PROPN PRON INTJ NOUN ADV NOUN DET NOUN INTJ PROPN INTJ PROPN ADP _ DET PROPN INTJ VERB DET NOUN CCONJ VERB DET NOUN ADP VERB PROPN ADP VERB DET NOUN
# ---
# Sentence : ra7 ngoul les sujets l khebawhom b les cagoules
# Predicted POS : PUNCT VERB DET NOUN DET NOUN ADP DET NOUN
# ---
# Sentence : dima m3a al khadra brabi b rabi rabhin m3a al magreb 123 dima algerier
# Predicted POS : ADV ADP DET PROPN VERB ADP PROPN VERB ADP DET NOUN INTJ ADV VERB
# ---
# Sentence : pour basma de sétif wallah tchoufi wach idirou 3aynik yahwalou wadnik yatwalou 123 viva l'algerie l' algerie wa echorouk
# Predicted POS : ADP VERB ADP NOUN INTJ NOUN PRON VERB VERB VERB VERB VERB INTJ VERB _ DET PROPN CCONJ VERB
# ---
# Sentence : 3lah ya chorouk wallah nhabkom 6 heures par jours m3akom w ntoma commentaire ma hotitoh ????????????
# Predicted POS : VERB INTJ PROPN INTJ NOUN VERB VERB VERB VERB PRON CCONJ ADV NOUN PART VERB VERB
# ---
# Sentence : sahlou 3alina rakoum msa3binha ahna walhih la douane tama3ine bezaf il fou controlie la douane sahitou
# Predicted POS : VERB VERB NOUN VERB PRON VERB DET NOUN VERB ADV PRON VERB VERB DET NOUN VERB
# ---
# Sentence : album wrah album fih probleme wra probleme
# Predicted POS : VERB VERB VERB PRON NOUN ADP NOUN
# ---
# Sentence : aller ga3 m3ana algerie 3 - 0 zambia
# Predicted POS : VERB ADV PRON PROPN INTJ PUNCT NUM PROPN
# ---
# Sentence : yakhi tmaskhir ndiro parabole colectife atgambri ya doula atgambri fi 3ode tchoufo halle nase kifah 3aychine m3a nar ou halle zawali ou machakelle lablade la blade djayinne tgololna barabolle ou klimatizor chkonne dakhalhom les parabole ou klimatizor ou dok afham ya faheme
# Predicted POS : INTJ INTJ PRON VERB VERB VERB INTJ NOUN VERB ADP NOUN VERB VERB VERB NOUN VERB ADP NOUN CCONJ VERB VERB CCONJ VERB VERB DET NOUN VERB VERB VERB CCONJ VERB VERB VERB DET NOUN CCONJ VERB CCONJ VERB VERB INTJ NOUN
# ---
# Sentence : zizou est tjs le grand cette fois si il parle aussi des grands ''m3ak y al khadra diri hala ''
# Predicted POS : INTJ VERB VERB DET NOUN DET NOUN VERB PRON VERB ADV DET NOUN VERB PRON DET PROPN VERB NOUN VERB
# ---
# Sentence : matkhafouche les fennecs ta3na inchalah nfarhou elouma el ouma el 3arabia wa el djazairia
# Predicted POS : VERB DET NOUN NOUN INTJ VERB VERB DET NOUN DET NOUN CCONJ DET NOUN
# ---
# Sentence : jamais lachite n7ab haroune rachid
# Predicted POS : ADV VERB VERB VERB VERB
# ---
# Sentence : pardon ya chourok amir el3ar el 3ar et non amir ray
# Predicted POS : VERB INTJ NOUN VERB VERB DET NOUN CCONJ PRON VERB NOUN
# ---
# Sentence : mala taherab m dar w tro7 l trotoire ti7 fi batard yedaha tol l les bars
# Predicted POS : VERB VERB ADP NOUN CCONJ VERB DET NOUN VERB ADP NOUN VERB VERB DET DET NOUN
# ---
# Sentence : Rabi m3akom et bon courage wled bledi
# Predicted POS : PROPN PRON CCONJ ADJ NOUN NOUN NOUN
# ---

# %%
from sklearn.metrics import accuracy_score, f1_score

def evaluate_metrics(model, dataloader, device, UNK_ID, PAD_ID=0):
    model.eval()
    all_preds, all_tags = [], []
    oov_preds, oov_tags = [], []
    known_preds, known_tags = [], []

    with torch.no_grad():
        for words, tags in dataloader:
            words = words.to(device)
            tags = tags.to(device)
            outputs = model(words)  # shape : (batch_size, seq_len, tagset_size)
            predictions = outputs.argmax(dim=-1)  # (batch_size, seq_len)

            # Parcourir chaque batch et chaque token
            for i in range(words.shape[0]):
                for j in range(words.shape[1]):
                    # Ignorer le padding
                    if tags[i, j].item() == PAD_ID:
                        continue
                    pred = predictions[i, j].item()
                    true = tags[i, j].item()
                    all_preds.append(pred)
                    all_tags.append(true)

                    # Si le token est OOV (celui-ci a été encodé par UNK_ID)
                    if words[i, j].item() == UNK_ID:
                        oov_preds.append(pred)
                        oov_tags.append(true)
                    else:
                        known_preds.append(pred)
                        known_tags.append(true)

    overall_acc = accuracy_score(all_tags, all_preds)
    overall_f1 = f1_score(all_tags, all_preds, average="macro")

    known_acc = accuracy_score(known_tags, known_preds) if known_tags else 0.0
    known_f1 = f1_score(known_tags, known_preds, average="macro") if known_tags else 0.0

    oov_acc = accuracy_score(oov_tags, oov_preds) if oov_tags else 0.0
    oov_f1 = f1_score(oov_tags, oov_preds, average="macro") if oov_tags else 0.0

    return {
        "overall_accuracy": overall_acc,
        "overall_f1": overall_f1,
        "known_accuracy": known_acc,
        "known_f1": known_f1,
        "oov_accuracy": oov_acc,
        "oov_f1": oov_f1
    }

# %%
for epoch in range(1, epochs+1):
    train_loss = train(model, train_loader, criterion, optimizer, device)
    dev_loss, dev_accuracy = evaluate(model, dev_loader, criterion, device)

    # Calcul des métriques détaillées (accuracy et F1 global, sur tokens connus et OOV)
    metrics = evaluate_metrics(model, dev_loader, device, UNK_ID, PAD_ID)

    print(f"Epoch {epoch}: train loss = {train_loss:.4f}, dev loss = {dev_loss:.4f}, dev accuracy = {dev_accuracy:.4f}")
    print("Overall Accuracy: {:.4f}, Overall F1: {:.4f}".format(metrics["overall_accuracy"], metrics["overall_f1"]))
    print("Known Accuracy: {:.4f}, Known F1: {:.4f}".format(metrics["known_accuracy"], metrics["known_f1"]))
    print("OOV Accuracy: {:.4f}, OOV F1: {:.4f}".format(metrics["oov_accuracy"], metrics["oov_f1"]))
# Out:
# Epoch 1: train loss = 1.1352, dev loss = 1.2482, dev accuracy = 0.6412
# Overall Accuracy: 0.6412, Overall F1: 0.5195
# Known Accuracy: 0.7978, Known F1: 0.6218
# OOV Accuracy: 0.4348, OOV F1: 0.0813
# Epoch 2: train loss = 1.1250, dev loss = 1.2482, dev accuracy = 0.6412
# Overall Accuracy: 0.6412, Overall F1: 0.5195
# Known Accuracy: 0.7978, Known F1: 0.6218
# OOV Accuracy: 0.4348, OOV F1: 0.0813
# Epoch 3: train loss = 1.1280, dev loss = 1.2482, dev accuracy = 0.6412
# Overall Accuracy: 0.6412, Overall F1: 0.5195
# Known Accuracy: 0.7978, Known F1: 0.6218
# OOV Accuracy: 0.4348, OOV F1: 0.0813
# Epoch 4: train loss = 1.1275, dev loss = 1.2482, dev accuracy = 0.6412
# Overall Accuracy: 0.6412, Overall F1: 0.5195
# Known Accuracy: 0.7978, Known F1: 0.6218
# OOV Accuracy: 0.4348, OOV F1: 0.0813
# Epoch 5: train loss = 1.1257, dev loss = 1.2482, dev accuracy = 0.6412
# Overall Accuracy: 0.6412, Overall F1: 0.5195
# Known Accuracy: 0.7978, Known F1: 0.6218
# OOV Accuracy: 0.4348, OOV F1: 0.0813
# Epoch 6: train loss = 1.1314, dev loss = 1.2482, dev accuracy = 0.6412
# Overall Accuracy: 0.6412, Overall F1: 0.5195
# Known Accuracy: 0.7978, Known F1: 0.6218
# OOV Accuracy: 0.4348, OOV F1: 0.0813
# Epoch 7: train loss = 1.1269, dev loss = 1.2482, dev accuracy = 0.6412
# Overall Accuracy: 0.6412, Overall F1: 0.5195
# Known Accuracy: 0.7978, Known F1: 0.6218
# OOV Accuracy: 0.4348, OOV F1: 0.0813
# Epoch 8: train loss = 1.1379, dev loss = 1.2482, dev accuracy = 0.6412
# Overall Accuracy: 0.6412, Overall F1: 0.5195
# Known Accuracy: 0.7978, Known F1: 0.6218
# OOV Accuracy: 0.4348, OOV F1: 0.0813
# Epoch 9: train loss = 1.1210, dev loss = 1.2482, dev accuracy = 0.6412
# Overall Accuracy: 0.6412, Overall F1: 0.5195
# Known Accuracy: 0.7978, Known F1: 0.6218
# OOV Accuracy: 0.4348, OOV F1: 0.0813
# Epoch 10: train loss = 1.1210, dev loss = 1.2482, dev accuracy = 0.6412
# Overall Accuracy: 0.6412, Overall F1: 0.5195
# Known Accuracy: 0.7978, Known F1: 0.6218
# OOV Accuracy: 0.4348, OOV F1: 0.0813

# %%
import torch
from conllu import parse_incr

# Définir l'appareil (GPU si disponible)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Charger le modèle et les vocabulaires (assurez-vous que load_model est défini dans le notebook)
model, Vw, Vi = load_model("/content/pos_tagger.pt", device)

# Ouvrir le fichier de prédictions en écriture
with open("/content/pred.conllu", "w", encoding="utf-8") as outf:
    # Lire le fichier de test
    with open("/content/qaf_arabizi-ud-test.conllu", "r", encoding="utf-8") as f:
        for sentence in parse_incr(f):
            # Prédire les POS pour la phrase
            predicted_tags = predict_sentence(model, sentence, Vw, Vi, device)
            # Mettre à jour le champ "upos" de chaque token avec la prédiction
            for token, tag in zip(sentence, predicted_tags):
                token["upos"] = tag
            # Écrire la phrase au format CoNLL-U dans le fichier de prédictions
            outf.write(sentence.serialize())
            outf.write("\n")

# Lancer l'évaluation avec accuracy.py
# !python accuracy.py -p pred.conllu -g qaf_arabizi-ud-test.conllu -t qaf_arabizi-ud-train.conllu -c upos -f form
# Out:
# <ipython-input-8-b68e48d3da73>:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# Predictions file: pred.conllu
# Accuracy on all upos: 64.85 ( 1489/ 2296)
# Accuracy on OOV upos: 43.90 (  349/  795)
